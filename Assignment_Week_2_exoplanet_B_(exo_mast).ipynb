# %% [markdown]
# <a href="https://colab.research.google.com/github/MGherardi07/Big-Data-in-Physics/blob/master/Assignment_Week_2_exoplanet_B_(exo_mast).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import requests
import matplotlib.pyplot as plt
import pandas as p
from IPython.display import display, HTML

# %matplotlib inline

planeturl = "https://exo.mast.stsci.edu/api/v0.1/exoplanets/"
dvurl = "https://exo.mast.stsci.edu/api/v0.1/dvdata/tess/"
header={}

# %%
planet_name = "HD 219666 b"

url = planeturl + "/identifiers/"

myparams = {"name":planet_name}

r = requests.get(url = url, params = myparams, headers = header)
print(r.headers.get('content-type'))
# Out:
# application/json; charset=UTF-8

# %%
planet_names = r.json()
ticid = planet_names['tessID']
tce = planet_names['tessTCE']
planet_names
# Out:
# {'canonicalName': 'HD 219666 b',
#  'dec': -56.903786,
#  'keplerID': None,
#  'keplerTCE': None,
#  'planetNames': [],
#  'ra': 349.556792,
#  'starName': 'HD 219666',
#  'tessID': 266980320,
#  'tessTCE': 'TCE_1'}

# %%
url = planeturl + planet_name + "/properties/"

r = requests.get(url = url, headers = header)

planet_prop = r.json()

print("Catalog 1: " + planet_prop[0]['catalog_name'])
#print("Catalog 2: " + planet_prop[1]['catalog_name'])
planet_prop[0].keys()
# Out:
# Catalog 1: nexsci
# dict_keys(['canonical_name', 'exoplanetID', 'catalog_name', 'planet_name', 'disposition', 'modified_date', 'star_name', 'component', 'Rs', 'Rs_unit', 'Rs_upper', 'Rs_lower', 'Rs_ref', 'Rs_url', 'Ms', 'Ms_unit', 'Ms_upper', 'Ms_lower', 'Ms_ref', 'Ms_url', 'Fe/H', 'Fe/H_upper', 'Fe/H_lower', 'Fe/H_ref', 'Fe/H_url', 'stellar_gravity', 'stellar_gravity_upper', 'stellar_gravity_lower', 'stellar_gravity_ref', 'stellar_gravity_url', 'Teff', 'Teff_unit', 'Teff_upper', 'Teff_lower', 'Teff_ref', 'Teff_url', 'Vmag', 'Vmag_unit', 'Vmag_upper', 'Vmag_lower', 'Vmag_ref', 'Vmag_url', 'Jmag', 'Jmag_unit', 'Jmag_upper', 'Jmag_lower', 'Jmag_ref', 'Jmag_url', 'Hmag', 'Hmag_unit', 'Hmag_upper', 'Hmag_lower', 'Hmag_ref', 'Hmag_url', 'Kmag', 'Kmag_unit', 'Kmag_upper', 'Kmag_lower', 'Kmag_ref', 'Kmag_url', 'RA', 'DEC', 'distance', 'distance_unit', 'distance_upper', 'distance_lower', 'distance_ref', 'distance_url', 'Rp', 'Rp_unit', 'Rp_upper', 'Rp_lower', 'Rp_ref', 'Rp_url', 'Mp', 'Mp_unit', 'Mp_upper', 'Mp_lower', 'Mp_ref', 'Mp_url', 'Tp', 'Tp_unit', 'Tp_upper', 'Tp_lower', 'Tp_ref', 'Tp_url', 'surface_gravity', 'surface_gravity_unit', 'surface_gravity_upper', 'surface_gravity_lower', 'surface_gravity_ref', 'surface_gravity_url', 'orbital_period', 'orbital_period_unit', 'orbital_period_upper', 'orbital_period_lower', 'orbital_period_ref', 'orbital_period_url', 'orbital_distance', 'orbital_distance_unit', 'orbital_distance_upper', 'orbital_distance_lower', 'orbital_distance_ref', 'orbital_distance_url', 'inclination', 'inclination_unit', 'inclination_upper', 'inclination_lower', 'inclination_ref', 'inclination_url', 'eccentricity', 'eccentricity_unit', 'eccentricity_upper', 'eccentricity_lower', 'eccentricity_ref', 'eccentricity_url', 'omega', 'omega_unit', 'omega_upper', 'omega_lower', 'omega_ref', 'omega_url', 'transit_duration', 'transit_duration_unit', 'transit_duration_upper', 'transit_duration_lower', 'transit_duration_ref', 'transit_duration_url', 'transit_time', 'transit_time_unit', 'transit_time_upper', 'transit_time_lower', 'transit_time_ref', 'transit_time_url', 'a/Rs', 'a/Rs_unit', 'a/Rs_upper', 'a/Rs_lower', 'a/Rs_ref', 'a/Rs_url', 'Rp/Rs', 'Rp/Rs_unit', 'Rp/Rs_upper', 'Rp/Rs_lower', 'Rp/Rs_ref', 'Rp/Rs_url', 'impact_parameter', 'impact_parameter_unit', 'impact_parameter_upper', 'impact_parameter_lower', 'impact_parameter_ref', 'impact_parameter_url', 'transit_depth', 'transit_depth_unit', 'transit_depth_upper', 'transit_depth_lower', 'transit_depth_ref', 'transit_depth_url', 'constellation', 'Tmag', 'Tmag_unit', 'Tmag_upper', 'Tmag_lower', 'Tmag_ref', 'Tmag_url', 'SNR', 'SNR_unit', 'SNR_upper', 'SNR_lower', 'SNR_ref', 'SNR_url', 'snr_emission_15', 'snr_emission_5', 'snr_transmission_K', 'pmRA', 'pmRA_upper', 'pmRA_lower', 'pmDec', 'pmDec_upper', 'pmDec_lower', 'pm_unit', 'pm_ref', 'pm_url', 'dayside_temperature', 'transit_flag'])

# %%
print("WASP-18 b Properties")
print("Stellar Mass %f %s" % (planet_prop[0]['Ms'], planet_prop[0]['Ms_unit'] ) )
print("Planet Mass %f %s" % (planet_prop[0]['Mp'], planet_prop[0]['Mp_unit'] ) )
print("Planet Mass Reference: %s" % (planet_prop[0]['Mp_ref']))
# Out:
# WASP-18 b Properties
# Stellar Mass 0.920000 M_sun
# Planet Mass 0.052230 M_Jupiter
# Planet Mass Reference: Esposito et al. 2018

# %%
url = dvurl + str(ticid) + '/tces/'
myparams = {"tce" : tce}

r = requests.get(url = url, params = myparams, headers = header)
sectorInfo = r.json()

sectors = [x[:11] for x in sectorInfo["TCE"] if tce in x]
sectors
# Out:
# ['s0001-s0001']

# %%
url = dvurl + str(ticid) + '/info/'
myparams = {"tce" : tce,
            "sector" : sectors[0]}

r = requests.get(url = url, params = myparams, headers = header)
tceInfo = r.json()
tceInfo.keys()
tceInfo['DV Data Header'].keys()

print("TIC: %s" % tceInfo['DV Primary Header']['OBJECT'])
print("Planet Radius: %f" % tceInfo['DV Data Header']['PRADIUS'])
# Out:
# TIC: TIC 266980320
# Planet Radius: 4.956255

# %%
# Get The data
url = dvurl + str(ticid) + '/table/'
myparams = {"tce" : tce,
            "sector" : sectors[0]}

r = requests.get(url = url, params = myparams, headers = header)
tce_data = r.json()

# %%
data = p.DataFrame.from_dict(tce_data['data'])
data.columns
# Out:
# Index(['TICID', 'EXTNAME', 'TIME', 'TIMECORR', 'CADENCENO', 'PHASE', 'LC_INIT',
#        'LC_INIT_ERR', 'LC_WHITE', 'LC_DETREND', 'MODEL_INIT', 'MODEL_WHITE',
#        'DATE_OBS', 'TESSDatetime', 'SECTORS'],
#       dtype='object')

# %%
detrend = data['LC_DETREND']
model = data['MODEL_INIT']
time = data['TIME']

plt.figure(figsize=(14,4))
plt.plot(time,detrend,'.',lw=0.4)
plt.plot(time,model,'r-',lw=0.6)
plt.xlabel('TIME (BTJD)')
plt.ylabel('Relative Flux')
# Out:
# Text(0, 0.5, 'Relative Flux')

# %%
url = dvurl + str(ticid) + '/phaseplot/'
myparams = {"tce" : tce,
            "sector" : sectors[0]}

r = requests.get(url = url, params = myparams, headers = header)

# %%
display(HTML(str(r.content.decode('utf-8'))))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Phased Light Curve</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-1.0.4.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.0.4.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="2c304d96-36b5-40e2-80d3-1059c661f8d0" data-root-id="16844"></div>
#
#
#
#
#
#         <script type="application/json" id="17019">
#           {"2692b8c3-2742-4930-934e-2e1859eb48fa":{"roots":{"references":[{"attributes":{},"id":"16867","type":"ResetTool"},{"attributes":{"label":{"value":"Binned"},"renderers":[{"id":"16893","type":"GlyphRenderer"}]},"id":"16903","type":"LegendItem"},{"attributes":{},"id":"16868","type":"SaveTool"},{"attributes":{"callback":null,"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[8691]},"y":{"__ndarray__":"...","dtype":"float64","shape":[8691]}},"selected":{"id":"16933","type":"Selection"},"selection_policy":{"id":"16934","type":"UnionRenderers"}},"id":"16904","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"16864","type":"PanTool"},{"id":"16865","type":"BoxZoomTool"},{"id":"16866","type":"WheelZoomTool"},{"id":"16867","type":"ResetTool"},{"id":"16868","type":"SaveTool"}]},"id":"16869","type":"Toolbar"},{"attributes":{"line_color":"#FF6600","x":{"field":"x"},"y":{"field":"y"}},"id":"16905","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"16870","type":"BoxAnnotation"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","x":{"field":"x"},"y":{"field":"y"}},"id":"16906","type":"Line"},{"attributes":{"data_source":{"id":"16877","type":"ColumnDataSource"},"glyph":{"id":"16878","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"16879","type":"Circle"},"selection_glyph":null,"view":{"id":"16881","type":"CDSView"}},"id":"16880","type":"GlyphRenderer"},{"attributes":{},"id":"16850","type":"LinearScale"},{"attributes":{"data_source":{"id":"16904","type":"ColumnDataSource"},"glyph":{"id":"16905","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"16906","type":"Line"},"selection_glyph":null,"view":{"id":"16908","type":"CDSView"}},"id":"16907","type":"GlyphRenderer"},{"attributes":{"source":{"id":"16877","type":"ColumnDataSource"}},"id":"16881","type":"CDSView"},{"attributes":{},"id":"16852","type":"LinearScale"},{"attributes":{"source":{"id":"16904","type":"ColumnDataSource"}},"id":"16908","type":"CDSView"},{"attributes":{},"id":"16884","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Phase (days)","formatter":{"id":"16884","type":"BasicTickFormatter"},"plot":{"id":"16844","subtype":"Figure","type":"Plot"},"ticker":{"id":"16855","type":"BasicTicker"}},"id":"16854","type":"LinearAxis"},{"attributes":{},"id":"16917","type":"Selection"},{"attributes":{},"id":"16886","type":"BasicTickFormatter"},{"attributes":{},"id":"16855","type":"BasicTicker"},{"attributes":{},"id":"16918","type":"UnionRenderers"},{"attributes":{"items":[{"id":"16889","type":"LegendItem"},{"id":"16903","type":"LegendItem"},{"id":"16919","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"16844","subtype":"Figure","type":"Plot"}},"id":"16888","type":"Legend"},{"attributes":{"plot":{"id":"16844","subtype":"Figure","type":"Plot"},"ticker":{"id":"16855","type":"BasicTicker"}},"id":"16858","type":"Grid"},{"attributes":{"label":{"value":"Transit Model"},"renderers":[{"id":"16907","type":"GlyphRenderer"}]},"id":"16919","type":"LegendItem"},{"attributes":{"label":{"value":"Detrended"},"renderers":[{"id":"16880","type":"GlyphRenderer"}]},"id":"16889","type":"LegendItem"},{"attributes":{"axis_label":"Relative Flux (ppm)","formatter":{"id":"16886","type":"BasicTickFormatter"},"plot":{"id":"16844","subtype":"Figure","type":"Plot"},"ticker":{"id":"16860","type":"BasicTicker"}},"id":"16859","type":"LinearAxis"},{"attributes":{"plot":{"id":"16844","subtype":"Figure","type":"Plot"},"text":"TIC 266980320 (S0001-S0001) TCE_1","text_font_size":{"value":"8pt"},"x":0,"x_offset":5,"x_units":"screen"," ...
